# %%
from texttable import Texttable

totalD,totalT,totalE,totalU,totalA = 12,12,12,4,6
totalAll = totalD+totalT+totalE+totalU

edxD, edxT, edxE, edxU, edxA = 7,7,3,2,2
edxTotal = edxD+edxT+edxE+edxU+edxA

tudD, tudT, tudE, tudU, tudA = 2,4,0,0,4
tudTotal = tudD + tudT + tudE + tudU + tudA

udemyD, udemyT, udemyE, udemyU, udemyA = 6,4,7,0,3
udemyTotal = udemyD + udemyT + udemyE + udemyU + udemyA

udacityD, udacityT, udacityE, udacityU, udacityA = 4,4,4,0,1
udacityTotal = udacityD + udacityT + udacityE + udacityU + udacityA

lyndaD, lyndaT, lyndaE, lyndaU, lyndaA = 5,3,4,0,4
lyndaTotal = lyndaD + lyndaT + lyndaE + lyndaU + lyndaA

coursD, coursT, coursE, coursU, coursA = 7,4,5,1,1
coursTotal = coursD + coursT + coursE + coursU + coursA

khanD, khanT, khanE, khanU, khanA = 4,7,2,4,3
khanTotal = khanD + khanT + khanE + khanU + khanA


table = Texttable()
table.set_cols_align(["c", "c", "c", "c", "c", "c", "c"])
table.set_cols_width([15,13,10,1,15,13,10])
#table.set_deco(Texttable.HEADER)
table.add_rows([['Platform', 'Type', '% Coverage','--','Platform', 'Type', '% Coverage'], 
                ['TUDelft Library', 'Descriptional', 'XXXX','-','edX', 'Descriptional', 'XXXX'], 
                ['TUDelft Library', 'Technical', 'XXXX','-','edX', 'Technical', 'XXXX'],
                ['TUDelft Library', 'Educational', 'XXXX','-','edX', 'Educational', 'XXXX'], 
                ['TUDelft Library', 'User related', 'XXXX','-','edX', 'User related', 'XXXX'],
                ['Udemy', 'Descriptional', 'XXXX','-','Udacity', 'Descriptional', 'XXXX'], 
                ['Udemy', 'Technical', 'XXXX','-','Udacity', 'Technical', 'XXXX'], 
                ['Udemy', 'Educational', 'XXXX','-','Udacity', 'Educational', 'XXXX'], 
                ['Udemy', 'User related', 'XXXX','-','Udacity', 'User related', 'XXXX'],
                ['Lynda', 'Descriptional', 'XXXX','-','Coursera', 'Descriptional', 'XXXX'], 
                ['Lynda', 'Technical', 'XXXX','-','Coursera', 'Technical', 'XXXX'], 
                ['Lynda', 'Educational', 'XXXX','-','Coursera', 'Educational', 'XXXX'], 
                ['Lynda', 'User related', 'XXXX','-','Coursera', 'User related', 'XXXX'],
                ['Khan Academy', 'Descriptional', 'XXXX','-','-','-','-'],
                ['Khan Academy', 'Technical', 'XXXX','-','-','-','-'],
                ['Khan Academy', 'Educational', 'XXXX','-','-','-','-'], 
                ['Khan Academy', 'User related', 'XXXX','-','-','-','-']])
print(table.draw())
# Out:
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |    Platform     |     Type      | % Coverage | - |    Platform     |     Type      | % Coverage |
# |                 |               |            | - |                 |               |            |
# +=================+===============+============+===+=================+===============+============+
# | TUDelft Library | Descriptional |    XXXX    | - |       edX       | Descriptional |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# | TUDelft Library |   Technical   |    XXXX    | - |       edX       |   Technical   |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# | TUDelft Library |  Educational  |    XXXX    | - |       edX       |  Educational  |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# | TUDelft Library | User related  |    XXXX    | - |       edX       | User related  |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Udemy      | Descriptional |    XXXX    | - |     Udacity     | Descriptional |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Udemy      |   Technical   |    XXXX    | - |     Udacity     |   Technical   |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Udemy      |  Educational  |    XXXX    | - |     Udacity     |  Educational  |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Udemy      | User related  |    XXXX    | - |     Udacity     | User related  |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Lynda      | Descriptional |    XXXX    | - |    Coursera     | Descriptional |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Lynda      |   Technical   |    XXXX    | - |    Coursera     |   Technical   |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Lynda      |  Educational  |    XXXX    | - |    Coursera     |  Educational  |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |      Lynda      | User related  |    XXXX    | - |    Coursera     | User related  |    XXXX    |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |  Khan Academy   | Descriptional |    XXXX    | - |        -        |       -       |     -      |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |  Khan Academy   |   Technical   |    XXXX    | - |        -        |       -       |     -      |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |  Khan Academy   |  Educational  |    XXXX    | - |        -        |       -       |     -      |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
# |  Khan Academy   | User related  |    XXXX    | - |        -        |       -       |     -      |
# +-----------------+---------------+------------+---+-----------------+---------------+------------+
